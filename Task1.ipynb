# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayan-98/DL-Lab_01/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# 1.	Create a random 4x4 array from an exponential distribution. Refer numpy functions

# %%
array_4x4 = np.random.exponential(scale=1.0, size=(4, 4))
print(array_4x4)
# Out:
# [[0.46065315 0.29769837 0.30975021 1.08180631]
#  [3.24426996 1.72920642 1.0722371  0.32874233]
#  [0.24422784 1.52632869 0.32433636 0.76358019]
#  [0.26731793 1.51786013 1.02804587 1.34839972]]

# %% [markdown]
# 2.	Create a random 100000x1 array from the same exponential distribution and visualize the distribution histogram along with uniform and normal distributions. Use the code given below and do the necessary changes. Change the number of bins and the plot view to make the visualization better.

# %%
data = np.random.exponential(scale=1.0, size=(100000, 1))

plt.hist(data, bins=100, density=True, histtype="step", color="blue", label="Exponential")
plt.hist(np.random.rand(100000), bins=100, density=True, histtype="step", color="red", label="Uniform")
plt.hist(np.random.randn(100000), bins=100, density=True, histtype="step", color="green", label="Normal")

plt.legend(loc="upper right")
plt.title("Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# 3.	Using matplotlib, plot the Z = X**2 + Y**2 in a 3D plot. Limit the x and y values to [-5, 5].

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = x**2 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')
ax.set_title('3D plot of Z = X^2 + Y^2')
plt.show()

# %% [markdown]
# 4.	Calculate the pearson standard coefficient and spearman rank correlation for the [HP, Attack, Defense, Sp. Ark, Sp. Def, Speed] features in the seaborn tutorial.ipynb. Visualize the results using heatmaps. Make sure the values are displaced in the heatmap as well.

# %%
# !ls
# Out:
# Pokemon.csv  sample_data

# %%
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# Select the relevant features
features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# Calculate Pearson correlation
pearson_corr = df[features].corr(method='pearson')

# Calculate Spearman rank correlation
spearman_corr = df[features].corr(method='spearman')


# Pearson correlation heatmap
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Pearson Correlation Heatmap')

# %%
#Spearman correlation heatmap
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Spearman Rank Correlation Heatmap')

plt.show()
